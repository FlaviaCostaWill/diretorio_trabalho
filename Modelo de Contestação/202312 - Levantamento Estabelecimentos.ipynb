# %%
import pandas as pd
import time
import os
import boto3
import io
import numpy as np
import string
import re
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
import lightgbm as lgbm
from matplotlib import pyplot as plt
import seaborn as sns
import shap
import joblib
import acessos as ac

# %%
query_string = '''
with base_chats as  (
-----------------HELPSHIFT -----------------
select distinct 
cast(issue.id_issue as varchar) as id_issue
	, dt_envio_mensagem
	, issue.cpf_customer
	, cast(issue.dt_criacao_chat as date) as dia_chat
	from cx_curated_zone.helpshift_issues_messages msg
	left join cx_curated_zone.helpshift_issues issue 
	on (issue.id_issue  = msg.id_issue)
	left join customer_curated_zone.ca_book_cliente ci 
	on (ci.cpf = issue.cpf_customer)
	where cast(dt_criacao_chat as date) >= to_date('2023-06-01', 'yyyy-mm-dd')
	and   cast(dt_criacao_chat as date) < to_date('2023-12-25', 'yyyy-mm-dd')
union all
---------------INTERCOM -------------------
select distinct 
m.id_issue 
	, m.dt_envio_mensagem
	, ci.cpf as cpf_customer
	, cast(i.dt_criacao as date) as dia_chat
	from cx_curated_zone.intercom_issues_messages m
left join cx_curated_zone.intercom_issues_id i on (i.id_issue = m.id_issue)
left join customer_curated_zone.ca_book_cliente ci on (ci.id_customer = i.id_customer)
	where cast(i.dt_criacao as timestamp) >= to_date('2023-06-01', 'yyyy-mm-dd')
	and   cast(i.dt_criacao as timestamp) < to_date('2023-12-25', 'yyyy-mm-dd')
)
, nao_reconhece as (
 select distinct o.*
   from base_chats o
    left join cx_curated_zone.helpshift_tag_niveis AS ht ON cast(o.id_issue as varchar) = cast(ht.id_issue as varchar)
    left join cx_curated_zone.tags_helpshift_intercom as ic on cast(o.id_issue as varchar) = cast(ic.id_issue as varchar)
   where coalesce(ht.nm_tag_hierarquia_4, ic.nm_tag_hierarquia_4) in ('Não reconhecimento de compra no crédito')
)
, estabelecimentos_nrc as (
select nr.*, tr.dt_dia , tr.ds_estabelecimento
from nao_reconhece nr 
inner join platform_curated_zone.transaction_dedicada_spending tr on (tr.cpf = nr.cpf_customer 
									and nr.dia_chat >= date_add('day', 0, cast(tr.dt_dia as date)) 
									and nr.dia_chat < date_add('day', 15, cast(tr.dt_dia as date)))
)
, estabelecimentos_total as (
select 
ds_estabelecimento
, dt_dia
, count(distinct cpf) as clientes_total
from platform_curated_zone.transaction_dedicada_spending
where cast(dt_dia as date) >= date_add('month', -1, date('2023-06-01'))
and cast(dt_dia as date) < to_date('2023-12-25', 'yyyy-mm-dd')
group by 1, 2
)
, agg_dia_estab as (
select
 e.ds_estabelecimento
, e.dt_dia
, max(t.ds_nome_estabelecimento_tratado) as ds_nome_estabelecimento_tratado
, max(t.ds_mcc_frequente) as ds_mcc_frequente
, max(t.ds_classificacao_nivel_4) as ds_classificacao_nivel_4
, max(t.ds_classificacao_nivel_3) as ds_classificacao_nivel_3
, count(distinct cpf_customer) as clientes_chat_nrc
, max(tot.clientes_total) as clientes_total_estab
, count(distinct id_issue) as issues
from estabelecimentos_nrc e
left join customer_curated_zone.ca_dict_merchant_classifier t on (e.ds_estabelecimento = t.ds_nome_estabelecimento)
left join estabelecimentos_total tot on (tot.ds_estabelecimento = e.ds_estabelecimento and tot.dt_dia = e.dt_dia)
where e.ds_estabelecimento is not null
group by 1, 2
)
select
ds_estabelecimento
, max(ds_nome_estabelecimento_tratado) as ds_nome_estabelecimento_tratado
, max(ds_mcc_frequente) as ds_mcc_frequente
, max(ds_classificacao_nivel_4) as ds_classificacao_nivel_4
, max(ds_classificacao_nivel_3) as ds_classificacao_nivel_3
, sum(issues) as issues
, sum(clientes_chat_nrc) as clientes_chat_nrc
, sum(clientes_chat_nrc) / cast(sum(clientes_total_estab) as double) as perc_chat_nrc
from agg_dia_estab
group by 1
having  sum(clientes_chat_nrc) > 20
order by perc_chat_nrc desc
limit 50000

 '''

# %%
user = 'flavia-costa'

# %%
data_to_predict = ac.df_athena_q(user, query_string)

# %%
len(data_to_predict)
# Out:
# 1733

# %%
data_to_predict.head(50)
# Out:
#          ds_estabelecimento ds_nome_estabelecimento_tratado  \
# 0   AUTO POSTO GABIROBA             AUTO POSTO GABIROBA
# 1       RECARGA*JULIANASOUZ             RECARGA*JULIANASOUZ
# 2   PG *SPORTBAY                    PG *SPORTBAY
# 3   DL     *GOOGLE ADS                               GOOGLE
# 4   PG *TON HELENA RAMAL            PG *TON HELENA RAMAL
# 5   IMPERIO DA R*IMPERIODA          IMPERIO DA R*IMPERIODA
# 6   GOOGLE ADS                                       GOOGLE
# 7        DL     *GOOGLE ADS                          GOOGLE
# 8    DicksSportingGoods.com          DicksSportingGoods.com
# 9   PG *BALLROOM                    PG *BALLROOM
# 10  GARAGEM STOR*GARAGEMST          GARAGEM STOR*GARAGEMST
# 11               Google ADS                          GOOGLE
# 12  SEBO ESTACAO CULTURAL           SEBO ESTACAO CULTURAL
# 13           BAR DO VITINHO                  BAR DO VITINHO
# 14       SUPERMERC FUJIKAWA              SUPERMERC FUJIKAWA
# 15       WL *STEAM PURCHASE                     STEAM GAMES
# 16  VINDI  *PIZZANOW                VINDI  *PIZZANOW
# 17                WEBMOTORS                       WEBMOTORS
# 18  WEBMOTORS                                     WEBMOTORS
# 19  SMILES FIDEL*COMPRADEM          SMILES FIDEL*COMPRADEM
# 20  IUGU*PRAQUERUMO                                    IUGU
# 21               META STORE                      META STORE
# 22         Vindi  *PizzaNow                Vindi  *PizzaNow
# 23     COMPASSION AUSTRALIA            COMPASSION AUSTRALIA
# 24        app.expertchat.me               app.expertchat.me
# 25  TMAXPAGAMENTOS                  TMAXPAGAMENTOS
# 26     Vindi  *RoyalBebidas            Vindi  *RoyalBebidas
# 27            WWW*SUPERACAO                   WWW*SUPERACAO
# 28  STAR MANIA                      STAR MANIA
# 29           TMAXPAGAMENTOS                  TMAXPAGAMENTOS
# 30  VENAARCOM                       VENAARCOM
# 31     SupportPDFfiller.com            SupportPDFfiller.com
# 32              WWW*UCCGIRL                     WWW*UCCGIRL
# 33  PAG*AS48988302469               PAG*AS48988302469
# 34          WWW*PAPELARIAVE                 WWW*PAPELARIAVE
# 35        PAG*AS48988302469               PAG*AS48988302469
# 36      EDC - INFRACOMMERCE             EDC - INFRACOMMERCE
# 37              METAPAY*ADS                     METAPAY*ADS
# 38  MP *MERCADOPAGOPO                          MERCADO PAGO
# 39  EROSORCOM                       EROSORCOM
# 40  PAG*ABX13VENDASECOM             PAG*ABX13VENDASECOM
# 41          IUGU*PRAQUERUMO                            IUGU
# 42         ZP          *SV3                ZP          *SV3
# 43          WWW*NANAKARANAE                 WWW*NANAKARANAE
# 44       NEXT SEGURO VIAGEM              NEXT SEGURO VIAGEM
# 45  UMANDRCOM                       UMANDRCOM
# 46   IMPERIO DA R*IMPERIODA          IMPERIO DA R*IMPERIODA
# 47               FIT CENTER                      FIT CENTER
# 48       www.HighRoller.com              www.HighRoller.com
# 49    SEBO ESTACAO CULTURAL           SEBO ESTACAO CULTURAL
#
#                                      ds_mcc_frequente  \
# 0                                 Postos Combustiveis
# 1          CASAS DE CAMBIO COMERCIANTE E CRIPTOMOEDAS
# 2           Suprimentos Industriais não Classificados
# 3               Comércio de Eletrônicos e Informática
# 4                        Conveniência / Delicatessens
# 5                                            Pet Shop
# 6                   Processamento de Dados e Serviços
# 7     SERVIÇOS DE PUBLICIDADE (ANUNCIOS E PROPAGANDA)
# 8                         LOJAS DE ARTIGOS ESPORTIVOS
# 9                                        Fornecedores
# 10                      Roupas Masculinas e Femininas
# 11        PROVEDORES DE ACESSO / REDE DE COMPUTADORES
# 12                                          Livrarias
# 13                                       RESTAURANTES
# 14                         SUPERMERCADOS E MERCEARIAS
# 15                       Mercadorias Digitais e Jogos
# 16                                        Lanchonetes
# 17              Comércio de Eletrônicos e Informática
# 18                                 Lojas de Descontos
# 19                               Vendas por Catálogos
# 20                  Processamento de Dados e Serviços
# 21  Aparelhos de Som / Televisores / Eletrodomésticos
# 22                                        LANCHONETES
# 23   ORGANIZAÇÕES DE SERVIÇOS BENEFICIENTES E SOCIAIS
# 24                               PIERCING / TATUAGENS
# 25              Comércio de Eletrônicos e Informática
# 26                         SUPERMERCADOS E MERCEARIAS
# 27                         ROUPA MASCULINA E FEMININA
# 28                  Câmeras Fotográficas e Acessórios
# 29              Comércio de Eletrônicos e Informática
# 30              Comércio de Eletrônicos e Informática
# 31                           PLANEJAMENTO DE REUNIÕES
# 32                         ROUPA MASCULINA E FEMININA
# 33                                        Seguradoras
# 34                           PLANEJAMENTO DE REUNIÕES
# 35                                        Seguradoras
# 36   SERVIÇOS DE PROGRAMAÇÃO DE COMPUTADORES E PROCES
# 37    SERVIÇOS DE PUBLICIDADE (ANUNCIOS E PROPAGANDA)
# 38                        Salão de Beleza / Barbearia
# 39              Comércio de Eletrônicos e Informática
# 40                     Profissionais Não Relacionados
# 41   SEX SHOP  / LOJAS DE MÁGICAS / ARTIGOS PARA FEST
# 42     CASAS DE LEILÃO / DESENHISTA GRÁFICOS / OUTROS
# 43                         ROUPA MASCULINA E FEMININA
# 44                                   SEGUROS EM GERAL
# 45              Comércio de Eletrônicos e Informática
# 46                                           Pet Shop
# 47                                 ACADEMIAS / CLUBES
# 48                   APOSTAS, CASAS LOTERICAS, BINGOS
# 49                                          LIVRARIAS
#
#                   ds_classificacao_nivel_4  \
# 0                 MOBILIDADE - COMBUSTIVEL
# 1                                    -  -
# 2           E-COMMERCE - VESTUARIO - GERAL
# 3                 E-COMMERCE - ELETRONICOS
# 4              SUPERMERCADO - DELICATESSEN
# 5                          PET - SAUDE PET
# 6                            SERVICOS - TI
# 7        SERVICOS - PUBLICIDADE / ANUNCIOS
# 8                   E-COMMERCE - ESPORTIVO
# 9                SERVICOS - DISTRIBUIDORES
# 10          E-COMMERCE - VESTUARIO - GERAL
# 11               TELECOM - PACOTES TELECOM
# 12                ENTRETENIMENTO - LEITURA
# 13  SERVICOS DE ALIMENTACAO - RESTAURANTES
# 14               SUPERMERCADO - VAREJISTAS
# 15       ENTRETENIMENTO - GAMES - JOGOS PC
# 16  SERVICOS DE ALIMENTACAO - RESTAURANTES
# 17                E-COMMERCE - ELETRONICOS
# 18          E-COMMERCE - VESTUARIO - GERAL
# 19          VIAGEM - OPERADORAS DE TURISMO
# 20     FINANCAS - PLATAFORMA DE PAGAMENTOS
# 21      LOJAS ESPECIALIZADAS - ELETRONICOS
# 22  SERVICOS DE ALIMENTACAO - RESTAURANTES
# 23                      SERVICOS - DOACOES
# 24                       SERVICOS - BELEZA
# 25                E-COMMERCE - ELETRONICOS
# 26                  ENTRETENIMENTO - BARES
# 27          E-COMMERCE - VESTUARIO - GERAL
# 28                 SERVICOS - FOTOGRAFICOS
# 29                E-COMMERCE - ELETRONICOS
# 30                E-COMMERCE - ELETRONICOS
# 31  SERVICOS - MATERIAL / EQUIP ESCRITORIO
# 32          E-COMMERCE - VESTUARIO - GERAL
# 33                         SEGURO - SEGURO
# 34  SERVICOS - MATERIAL / EQUIP ESCRITORIO
# 35                         SEGURO - SEGURO
# 36                           SERVICOS - TI
# 37       SERVICOS - PUBLICIDADE / ANUNCIOS
# 38             FINANCAS - CARTEIRA DIGITAL
# 39                E-COMMERCE - ELETRONICOS
# 40             SERVICOS - NAO ESPECIFICADO
# 41     FINANCAS - PLATAFORMA DE PAGAMENTOS
# 42             SERVICOS - NAO ESPECIFICADO
# 43          E-COMMERCE - VESTUARIO - GERAL
# 44                         SEGURO - SEGURO
# 45                E-COMMERCE - ELETRONICOS
# 46                         PET - SAUDE PET
# 47                       SAUDE - ACADEMIAS
# 48               ENTRETENIMENTO - LOTERIAS
# 49                ENTRETENIMENTO - LEITURA
#
#                   ds_classificacao_nivel_3  issues  clientes_chat_nrc  \
# 0                 MOBILIDADE - COMBUSTIVEL      21                 21
# 1                                       -      145                 26
# 2                   E-COMMERCE - VESTUARIO      68                 31
# 3                 E-COMMERCE - ELETRONICOS      93                 34
# 4              SUPERMERCADO - DELICATESSEN     101                 34
# 5                          PET - SAUDE PET     307                119
# 6                            SERVICOS - TI     135                 61
# 7        SERVICOS - PUBLICIDADE / ANUNCIOS      43                 21
# 8                   E-COMMERCE - ESPORTIVO      60                 38
# 9                SERVICOS - DISTRIBUIDORES      57                 27
# 10                  E-COMMERCE - VESTUARIO     121                 48
# 11               TELECOM - PACOTES TELECOM      96                 45
# 12                ENTRETENIMENTO - LEITURA      61                 26
# 13  SERVICOS DE ALIMENTACAO - RESTAURANTES      99                 38
# 14               SUPERMERCADO - VAREJISTAS      41                 24
# 15                  ENTRETENIMENTO - GAMES      59                 24
# 16  SERVICOS DE ALIMENTACAO - RESTAURANTES     114                 51
# 17                E-COMMERCE - ELETRONICOS      52                 26
# 18                  E-COMMERCE - VESTUARIO      55                 21
# 19          VIAGEM - OPERADORAS DE TURISMO      70                 29
# 20     FINANCAS - PLATAFORMA DE PAGAMENTOS      73                 28
# 21      LOJAS ESPECIALIZADAS - ELETRONICOS      95                 44
# 22  SERVICOS DE ALIMENTACAO - RESTAURANTES      87                 36
# 23                      SERVICOS - DOACOES     116                 55
# 24                       SERVICOS - BELEZA      54                 26
# 25                E-COMMERCE - ELETRONICOS     229                 86
# 26                  ENTRETENIMENTO - BARES      84                 30
# 27                  E-COMMERCE - VESTUARIO     119                 61
# 28                 SERVICOS - FOTOGRAFICOS      58                 31
# 29                E-COMMERCE - ELETRONICOS     152                 82
# 30                E-COMMERCE - ELETRONICOS      75                 32
# 31  SERVICOS - MATERIAL / EQUIP ESCRITORIO      37                 21
# 32                  E-COMMERCE - VESTUARIO      86                 38
# 33                         SEGURO - SEGURO      43                 26
# 34  SERVICOS - MATERIAL / EQUIP ESCRITORIO      39                 25
# 35                         SEGURO - SEGURO      66                 37
# 36                           SERVICOS - TI      65                 27
# 37       SERVICOS - PUBLICIDADE / ANUNCIOS      60                 27
# 38             FINANCAS - CARTEIRA DIGITAL     109                 64
# 39                E-COMMERCE - ELETRONICOS      77                 45
# 40             SERVICOS - NAO ESPECIFICADO      73                 31
# 41     FINANCAS - PLATAFORMA DE PAGAMENTOS     102                 48
# 42             SERVICOS - NAO ESPECIFICADO      69                 39
# 43                  E-COMMERCE - VESTUARIO      66                 36
# 44                         SEGURO - SEGURO     122                 66
# 45                E-COMMERCE - ELETRONICOS      69                 42
# 46                         PET - SAUDE PET     201                111
# 47                       SAUDE - ACADEMIAS      51                 22
# 48               ENTRETENIMENTO - LOTERIAS      81                 36
# 49                ENTRETENIMENTO - LEITURA      82                 32
#
#     perc_chat_nrc
# 0        1.000000
# 1        0.962963
# 2        0.939394
# 3        0.918919
# 4        0.918919
# 5        0.901515
# 6        0.884058
# 7        0.875000
# 8        0.844444
# 9        0.843750
# 10       0.842105
# 11       0.818182
# 12       0.812500
# 13       0.808511
# 14       0.800000
# 15       0.800000
# 16       0.796875
# 17       0.787879
# 18       0.777778
# 19       0.763158
# 20       0.736842
# 21       0.733333
# 22       0.720000
# 23       0.705128
# 24       0.684211
# 25       0.682540
# 26       0.681818
# 27       0.677778
# 28       0.673913
# 29       0.672131
# 30       0.666667
# 31       0.656250
# 32       0.644068
# 33       0.634146
# 34       0.625000
# 35       0.616667
# 36       0.613636
# 37       0.613636
# 38       0.609524
# 39       0.608108
# 40       0.607843
# 41       0.600000
# 42       0.590909
# 43       0.590164
# 44       0.584071
# 45       0.583333
# 46       0.581152
# 47       0.578947
# 48       0.571429
# 49       0.561404

# %%
#data_to_predict['indice'] = data_to_predict['ds_estabelecimento'].str.find('*')
#tratado2

# %%
data_to_predict['indice'] = data_to_predict['ds_estabelecimento'].str.split('*')

# %%
data_to_predict['pos_asterisco'] = data_to_predict['indice'].str[1]

# %%
data_to_predict['ds_nome_estabelecimento_tratado'] = np.where(data_to_predict['ds_nome_estabelecimento_tratado'] != data_to_predict['ds_estabelecimento'], 
                                                      data_to_predict['ds_nome_estabelecimento_tratado'], 
                                                      np.where(data_to_predict['ds_estabelecimento'].str.find('*') != -1, data_to_predict['pos_asterisco'], data_to_predict['ds_estabelecimento'] ))

# %%
data_to_predict['ds_nome_estabelecimento_tratado2'] = data_to_predict['ds_nome_estabelecimento_tratado'].str.upper()

# %%
data_to_predict.head(10)
# Out:
#         ds_estabelecimento ds_nome_estabelecimento_tratado  \
# 0  AUTO POSTO GABIROBA             AUTO POSTO GABIROBA
# 1      RECARGA*JULIANASOUZ                     JULIANASOUZ
# 2  PG *SPORTBAY                        SPORTBAY
# 3  DL     *GOOGLE ADS                               GOOGLE
# 4  PG *TON HELENA RAMAL                TON HELENA RAMAL
# 5  IMPERIO DA R*IMPERIODA                       IMPERIODA
# 6  GOOGLE ADS                                       GOOGLE
# 7       DL     *GOOGLE ADS                          GOOGLE
# 8   DicksSportingGoods.com          DicksSportingGoods.com
# 9  PG *BALLROOM                        BALLROOM
#
#                                   ds_mcc_frequente  \
# 0                              Postos Combustiveis
# 1       CASAS DE CAMBIO COMERCIANTE E CRIPTOMOEDAS
# 2        Suprimentos Industriais não Classificados
# 3            Comércio de Eletrônicos e Informática
# 4                     Conveniência / Delicatessens
# 5                                         Pet Shop
# 6                Processamento de Dados e Serviços
# 7  SERVIÇOS DE PUBLICIDADE (ANUNCIOS E PROPAGANDA)
# 8                      LOJAS DE ARTIGOS ESPORTIVOS
# 9                                     Fornecedores
#
#             ds_classificacao_nivel_4           ds_classificacao_nivel_3  \
# 0           MOBILIDADE - COMBUSTIVEL           MOBILIDADE - COMBUSTIVEL
# 1                              -  -                                  -
# 2     E-COMMERCE - VESTUARIO - GERAL             E-COMMERCE - VESTUARIO
# 3           E-COMMERCE - ELETRONICOS           E-COMMERCE - ELETRONICOS
# 4        SUPERMERCADO - DELICATESSEN        SUPERMERCADO - DELICATESSEN
# 5                    PET - SAUDE PET                    PET - SAUDE PET
# 6                      SERVICOS - TI                      SERVICOS - TI
# 7  SERVICOS - PUBLICIDADE / ANUNCIOS  SERVICOS - PUBLICIDADE / ANUNCIOS
# 8             E-COMMERCE - ESPORTIVO             E-COMMERCE - ESPORTIVO
# 9          SERVICOS - DISTRIBUIDORES          SERVICOS - DISTRIBUIDORES
#
#    issues  clientes_chat_nrc  perc_chat_nrc                      indice  \
# 0      21                 21       1.000000   [AUTO POSTO GABIROBA    ]
# 1     145                 26       0.962963      [RECARGA, JULIANASOUZ]
# 2      68                 31       0.939394  [PG , SPORTBAY           ]
# 3      93                 34       0.918919  [DL     , GOOGLE ADS     ]
# 4     101                 34       0.918919  [PG , TON HELENA RAMAL   ]
# 5     307                119       0.901515  [IMPERIO DA R, IMPERIODA ]
# 6     135                 61       0.884058   [GOOGLE ADS             ]
# 7      43                 21       0.875000       [DL     , GOOGLE ADS]
# 8      60                 38       0.844444    [DicksSportingGoods.com]
# 9      57                 27       0.843750  [PG , BALLROOM           ]
#
#          pos_asterisco ds_nome_estabelecimento_tratado2
# 0                  NaN          AUTO POSTO GABIROBA
# 1          JULIANASOUZ                      JULIANASOUZ
# 2  SPORTBAY                         SPORTBAY
# 3      GOOGLE ADS                                GOOGLE
# 4  TON HELENA RAMAL                 TON HELENA RAMAL
# 5           IMPERIODA                        IMPERIODA
# 6                  NaN                           GOOGLE
# 7           GOOGLE ADS                           GOOGLE
# 8                  NaN           DICKSSPORTINGGOODS.COM
# 9  BALLROOM                         BALLROOM

# %%
data_to_predict.sort_values(by = 'clientes_chat_nrc', ascending = False)
# Out:
#            ds_estabelecimento ds_nome_estabelecimento_tratado  \
# 1683     Uber   *UBER   *TRIP                            UBER
# 1694       99APP       *99App                           99App
# 1682  UBER   *UBER   *TRIP                               UBER
# 1579           APPLE.COM/BILL                           APPLE
# 1673  99APP       *99APP                           99APP
# ...                       ...                             ...
# 425     PANIFICADORA E LANCHO           PANIFICADORA E LANCHO
# 421         PADARIA PAO NOSSO               PADARIA PAO NOSSO
# 414                     GAZIN                           GAZIN
# 408       LOJAS LE BISCUIT SA                LOJAS LE BISCUIT
# 0     AUTO POSTO GABIROBA             AUTO POSTO GABIROBA
#
#            ds_mcc_frequente                          ds_classificacao_nivel_4  \
# 1683        TAXI E LIMUSINE  MOBILIDADE - TRANSPORTE PRIVADO - APP TRANSPORTE
# 1694        TAXI E LIMUSINE           MOBILIDADE - TRANSPORTE PRIVADO - TAXIS
# 1682      Taxi / Limousines  MOBILIDADE - TRANSPORTE PRIVADO - APP TRANSPORTE
# 1579                 Discos                ENTRETENIMENTO - STREAMING - AUDIO
# 1673      Taxi / Limousines           MOBILIDADE - TRANSPORTE PRIVADO - TAXIS
# ...                     ...                                               ...
# 425                Padarias                SERVICOS DE ALIMENTACAO - PADARIAS
# 421                Padarias                SERVICOS DE ALIMENTACAO - PADARIAS
# 414   Lojas de Departamento                       E-COMMERCE - MULTICATEGORIA
# 408   Lojas de Departamento            LOJAS DE DEPARTAMENTO - MULTICATEGORIA
# 0       Postos Combustiveis                          MOBILIDADE - COMBUSTIVEL
#
#                     ds_classificacao_nivel_3  issues  clientes_chat_nrc  \
# 1683         MOBILIDADE - TRANSPORTE PRIVADO   34352              22752
# 1694         MOBILIDADE - TRANSPORTE PRIVADO   21203              13790
# 1682         MOBILIDADE - TRANSPORTE PRIVADO   17372               9912
# 1579              ENTRETENIMENTO - STREAMING   14326               8679
# 1673         MOBILIDADE - TRANSPORTE PRIVADO   10812               6134
# ...                                      ...     ...                ...
# 425       SERVICOS DE ALIMENTACAO - PADARIAS      27                 21
# 421       SERVICOS DE ALIMENTACAO - PADARIAS      25                 21
# 414              E-COMMERCE - MULTICATEGORIA      23                 21
# 408   LOJAS DE DEPARTAMENTO - MULTICATEGORIA      29                 21
# 0                   MOBILIDADE - COMBUSTIVEL      21                 21
#
#       perc_chat_nrc                       indice pos_asterisco  \
# 1683       0.008458     [Uber   , UBER   , TRIP]       UBER
# 1694       0.008161        [99APP       , 99App]         99App
# 1682       0.008465  [UBER   , UBER   , TRIP   ]       UBER
# 1579       0.012457             [APPLE.COM/BILL]           NaN
# 1673       0.008851   [99APP       , 99APP     ]    99APP
# ...             ...                          ...           ...
# 425        0.069536      [PANIFICADORA E LANCHO]           NaN
# 421        0.070000          [PADARIA PAO NOSSO]           NaN
# 414        0.071918                      [GAZIN]           NaN
# 408        0.072917        [LOJAS LE BISCUIT SA]           NaN
# 0          1.000000    [AUTO POSTO GABIROBA    ]           NaN
#
#      ds_nome_estabelecimento_tratado2
# 1683                             UBER
# 1694                            99APP
# 1682                             UBER
# 1579                            APPLE
# 1673                       99APP
# ...                               ...
# 425             PANIFICADORA E LANCHO
# 421                 PADARIA PAO NOSSO
# 414                             GAZIN
# 408                  LOJAS LE BISCUIT
# 0             AUTO POSTO GABIROBA
#
# [1733 rows x 11 columns]

# %%
#data_to_predict.query('ds_estabelecimento.str.contains("AHESUPCOM")')
